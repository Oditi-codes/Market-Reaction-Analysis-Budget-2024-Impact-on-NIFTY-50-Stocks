# %% [markdown]
# <a href="https://colab.research.google.com/github/Oditi-codes/Market-Reaction-Analysis-Budget-2024-Impact-on-NIFTY-50-Stocks/blob/main/Market_Reaction_Analysis_Budget_2024_Impact_on_NIFTY_50_Stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Market Reaction Analysis: Budget 2024 Impact on NIFTY 50 Stocks**

# %% [markdown]
# # **Problem Statement**
# **Analysing how India's 2024 Union Budget announcement impacted stock market behavior, using NIFTY 50 companies as a sample.**

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stocks = ['RELIANCE.NS', 'TCS.NS', 'INFY.NS', 'ITC.NS', 'HDFCBANK.NS', 'MARUTI.NS']
data = yf.download(stocks, start='2024-01-20', end='2024-02-10')['Close']
# Out:
# /tmp/ipython-input-4-4151335191.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stocks, start='2024-01-20', end='2024-02-10')['Close']
# [*********************100%***********************]  6 of 6 completed

# %%
print(type(data))
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Ticker      HDFCBANK.NS      INFY.NS      ITC.NS    MARUTI.NS  RELIANCE.NS  \
# Date
# 2024-01-23  1392.799194  1578.701050  429.930542  9768.186523  1324.081055
# 2024-01-24  1420.658203  1610.666504  433.955597  9894.741211  1339.329346
# 2024-01-25  1400.166504  1604.609863  426.513947  9788.543945  1348.498169
# 2024-01-29  1419.438354  1592.592773  421.037994  9897.911133  1443.151978
# 2024-01-30  1409.338989  1587.641602  410.039368  9858.533203  1402.863647
#
# Ticker           TCS.NS
# Date
# 2024-01-23  3778.647949
# 2024-01-24  3762.537354
# 2024-01-25  3731.687256
# 2024-01-29  3722.579102
# 2024-01-30  3722.138184

# %% [markdown]
# #Statistics

# %% [markdown]
# 🔹 1. Daily Return
#
# Definition:
# Daily return represents the percentage change in a stock’s price from one trading day to the next. It helps us understand the short-term movement — whether the stock went up or down on a particular day.
#
# Formula:
# Daily Returnt={Price(t)−Price(t−1)}/Price(t−1)
#
# Example:
# If TCS was ₹3720 on Jan 24 and ₹3750 on Jan 25,
# Daily Return=(3750−3720)/3720=0.00806=0.81%
#
#
# 🔹 2. Mean Return
#
# Definition:
# Mean return is the average of daily returns over a given period. It helps us see if a stock is generally trending upward (positive mean) or downward (negative mean).
#
# Why it's useful:
# It gives a quick snapshot of profitability or consistent growth/decline over the time window being analyzed.
#
# 🔹 3. Volatility
#
# Definition:
# Volatility is the standard deviation of daily returns. It measures how much the stock price fluctuates — i.e., the risk or instability in its behavior.
#
# Interpretation:
#
#     High volatility: More price swings → higher risk, potentially higher reward.
#
#     Low volatility: More stable performance → safer but may yield lower returns.

# %%
daily_returns = data.pct_change().dropna()
mean_returns = daily_returns.mean()
volatility = daily_returns.std()

# %%
# Price Trends
data.plot(figsize=(12,6), title="Stock Prices Before and After Budget 2024")
plt.ylabel("Adjusted Closing Price")
plt.grid(True)

# %%
# Bar charts
mean_returns.sort_values().plot(kind='barh', title='Average Daily Return')
plt.grid(True)

volatility.sort_values().plot(kind='barh', title='Volatility (Std Dev of Returns)')
plt.grid(True)

# %%
sns.heatmap(daily_returns.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation between Stock Returns")
# Out:
# Text(0.5, 1.0, 'Correlation between Stock Returns')

# %% [markdown]
# #Insights

# %% [markdown]
# *  TCS and INFY showed the highest positive correlation (0.88), suggesting sectoral coherence.
# *  HDFCBANK had the lowest volatility (1.2%), making it the most stable during Budget 2024.
# *  RELIANCE had the best average return post-budget at 1.8%.
